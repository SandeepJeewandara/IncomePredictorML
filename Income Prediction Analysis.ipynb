# %% [markdown]
# ### Load Basic Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Dataset

# %%
from ucimlrepo import fetch_ucirepo 

# fetch dataset 
adult = fetch_ucirepo(id=2) 
df = adult['data']['original']

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
# Check the Data Types 
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
# See is there any null values in  the dataset
df.isnull().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# income              0
# dtype: int64

# %%
# FIll all null values in Dataframe
df.fillna('Unknown', inplace=True)

# %%
# See how many Unique values and categories belong to each class
df.nunique()
# Out:
# age                  74
# workclass            10
# fnlwgt            28523
# education            16
# education-num        16
# marital-status        7
# occupation           16
# relationship          6
# race                  5
# sex                   2
# capital-gain        123
# capital-loss         99
# hours-per-week       96
# native-country       43
# income                4
# dtype: int64

# %%
#See how are the data distributed
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             48842.0      38.643585      13.710510     17.0      28.0
# fnlwgt          48842.0  189664.134597  105604.025423  12285.0  117550.5
# education-num   48842.0      10.078089       2.570973      1.0       9.0
# capital-gain    48842.0    1079.067626    7452.019058      0.0       0.0
# capital-loss    48842.0      87.502314     403.004552      0.0       0.0
# hours-per-week  48842.0      40.422382      12.391444      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178144.5  237642.0  1490400.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %% [markdown]
# ### Value Counts in Each Classes

# %%
# See value counts in each class
df['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# ?                    1836
# Self-emp-inc         1695
# Federal-gov          1432
# Unknown               963
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df['education-num'].value_counts()
# Out:
# education-num
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: count, dtype: int64

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# ?                    1843
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Unknown               966
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
df['relationship'].value_counts()
# Out:
# relationship
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
df['race'].value_counts()
# Out:
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               583
# Philippines                     295
# Unknown                         274
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# ...

# %%
df['income'].value_counts()
# Out:
# income
# <=50K     24720
# <=50K.    12435
# >50K       7841
# >50K.      3846
# Name: count, dtype: int64

# %%
# Clean up income categories
df['income'] = df['income'].str.strip('.')
df['income'] = df['income'].str.strip()

# %%
df['income'].value_counts()
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
# Plot relationships among different  features 
plt.figure(figsize=(6, 4))
sns.countplot(x='income', palette='coolwarm',  hue='race',data=df);
plt.show()

# %% [markdown]
# ### Filling Null Values

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
# Replacing missing Values
df['workclass'] = df['workclass'].replace(['?','Unknown'],'Private')
df['occupation'] = df['occupation'].replace(['?','Unknown'],'Prof-specialty')
df['native-country'] = df['native-country'].replace(['?','Unknown'],'United-States')

# %%
#See is there any null values in  the dataset
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             36705
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# ### Feature Engineering

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
# Education Category Grouping levels
df['education']= df['education'].replace(['Preschool','1st-4th','5th-6th','7th-8th','9th','10th','11th','12th'], 'School')
df['education']= df['education'].replace(['Assoc-voc','Assoc-acdm','Prof-school','Some-college'], 'Undergraduate')

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad          15784
# Undergraduate    15374
# Bachelors         8025
# School            6408
# Masters           2657
# Doctorate          594
# Name: count, dtype: int64

# %%
# Marital-Status Category Grouping levels
df['marital-status']= df['marital-status'].replace(['Married-AF-spouse','Married-civ-spouse'], 'Married')
df['marital-status']= df['marital-status'].replace(['Divorced','Separated','Widowed','Married-spouse-absent'],'Other')

# %%
df['marital-status'].value_counts()
# Out:
# marital-status
# Married          22416
# Never-married    16117
# Other            10309
# Name: count, dtype: int64

# %%
# Income Category value replce
df['income']= df['income'].replace('>50K', 1)
df['income']= df['income'].replace('<=50K',0)

# %%
df['income'].value_counts()
# Out:
# income
# 0    37155
# 1    11687
# Name: count, dtype: int64

# %%
# Plot relationships among different  features
plt.figure(figsize=(6, 4))
sns.countplot(x='income', palette='coolwarm',  hue='education',data=df);
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
# Correlation Analysis
numeric_df = df.select_dtypes(include=['int64', 'float64'])
correlation_matrix = numeric_df.corr()

# Display correlation matrix
correlation_matrix
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076628       0.030940      0.077229      0.056944
# fnlwgt         -0.076628  1.000000      -0.038761     -0.003706     -0.004366
# education-num   0.030940 -0.038761       1.000000      0.125146      0.080972
# capital-gain    0.077229 -0.003706       0.125146      1.000000     -0.031441
# capital-loss    0.056944 -0.004366       0.080972     -0.031441      1.000000
# hours-per-week  0.071558 -0.013519       0.143689      0.082157      0.054467
# income          0.230369 -0.006339       0.332613      0.223013      0.147554
#
#                 hours-per-week    income
# age                   0.071558  0.230369
# fnlwgt               -0.013519 -0.006339
# education-num         0.143689  0.332613
# capital-gain          0.082157  0.223013
# capital-loss          0.054467  0.147554
# hours-per-week        1.000000  0.227687
# income                0.227687  1.000000

# %%
# Plot Correlation Matrix

plt.figure(figsize=(5, 4))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Drop fnlwgt and education Column from Datafram
df.drop(['fnlwgt'], axis=1, inplace=True)
df.drop(['education'], axis=1, inplace=True)

# %% [markdown]
# ### Identify Outliers

# %% [markdown]
# #### Histogram

# %%
# Plot Histogram to study the shape of the numeric data
df.hist(figsize=(11,11), layout=(3,3), sharex=False);

# %% [markdown]
# ### Boxplot

# %%
# Plot Boxplot to see Outliers
df.plot(kind= 'box', figsize=(11,11), layout=(3,3), sharex=False, subplots=True);

# %% [markdown]
# ## Model Building

# %%
X = df.drop(['income'], axis=1)
y = df['income']

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# Get the copy of the Dataframe
df_new = df.copy()

# Apply label encoding to all columns using the apply method
df_new = df_new.apply(LabelEncoder().fit_transform)

# %%
df_new.head(10)
# Out:
#    age  workclass  education-num  marital-status  occupation  relationship  \
# 0   22          6             12               1           0             1
# 1   33          5             12               0           3             0
# 2   21          3              8               2           5             1
# 3   36          3              6               0           5             0
# 4   11          3             12               0           9             5
# 5   20          3             13               0           3             5
# 6   32          3              4               2           7             1
# 7   35          5              8               0           3             0
# 8   14          3             13               1           9             1
# 9   25          3             12               0           3             0
#
#    race  sex  capital-gain  capital-loss  hours-per-week  native-country  \
# ...

# %%
# Define StandardScaler
ss = StandardScaler().fit(df_new.drop('income',axis=1))

# %%
# Scale the numerical features
X = ss.transform(df_new.drop('income', axis=1))
y = df['income']

# %%
# Get Correlation Matrix for all variables
correlation_matrix = df_new.corr()

# %%
# Plot Correlation Matrix

plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### Devide the Dataset for Training and Testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=40)

# %% [markdown]
# #### Define Function to Evaluate model Results

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score,confusion_matrix, classification_report

# Function to get training Scores   
def training_scores(y_act, y_pred):
    print("\n ======= Training Classification Report ==========")
    acc = round(accuracy_score(y_act, y_pred), 3)
    print(classification_report(y_act,y_pred))
    cm = confusion_matrix(y_act, y_pred)
    print("Training Accuracy: ",acc)
    
# Function to get validation Scores    
def validation_scores(y_act, y_pred):
    print("\n ======= Testing Classification Report ==========")
    acc = round(accuracy_score(y_act, y_pred), 3)
    print(classification_report(y_act,y_pred))
    cm = confusion_matrix(y_act, y_pred)
    print("Testing Accuracy: ",acc)

         

    # Plot Confusion Matrix
    plt.figure(figsize=(3, 3))
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', cbar=False)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('\nConfusion Matrix')
    plt.show()

# %% [markdown]
# ### Naive Bias

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize Gaussian Naive Bayes classifier
nb_classifier = GaussianNB()

# Train the model
nb_model = nb_classifier.fit(X_train, y_train)

# Predictions
train_predict = nb_model.predict(X_train)
test_predict = nb_model.predict(X_test)

# Calculate and print scores
training_scores(y_train, train_predict)
validation_scores(y_test, test_predict)
# Out:
#  ======= Training Classification Report ==========
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89     26047
#            1       0.67      0.48      0.56      8142
#
#     accuracy                           0.82     34189
#    macro avg       0.76      0.70      0.72     34189
# weighted avg       0.81      0.82      0.81     34189
#
# Training Accuracy:  0.82
#
#  ======= Testing Classification Report ==========
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88     11108
#            1       0.66      0.46      0.54      3545
#
#     accuracy                           0.81     14653
#    macro avg       0.75      0.69      0.71     14653
# weighted avg       0.80      0.81      0.80     14653
#
# Testing Accuracy:  0.812

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, VotingClassifier

# Initialize Random Forest classifier
rf_classifier = RandomForestClassifier()

# Train the model
rf_model = rf_classifier.fit(X_train, y_train)

# Predictions
train_predict = rf_model.predict(X_train)
test_predict = rf_model.predict(X_test)

# Calculate and print scores
training_scores(y_train, train_predict)
validation_scores(y_test, test_predict)
# Out:
#  ======= Training Classification Report ==========
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     26047
#            1       0.96      0.93      0.95      8142
#
#     accuracy                           0.97     34189
#    macro avg       0.97      0.96      0.96     34189
# weighted avg       0.97      0.97      0.97     34189
#
# Training Accuracy:  0.975
#
#  ======= Testing Classification Report ==========
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90     11108
#            1       0.72      0.61      0.66      3545
#
#     accuracy                           0.85     14653
#    macro avg       0.80      0.77      0.78     14653
# weighted avg       0.84      0.85      0.84     14653
#
# Testing Accuracy:  0.848

# %% [markdown]
# ### Model Optimization

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
}

# Initialize Random Forest classifier
rf = RandomForestClassifier()

# Perform Grid Search to find the Best Hyperparameters
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, scoring='accuracy', cv=5)
grid_search.fit(X, y)

# Get the Best Hyperparameters and the Model
best_params = grid_search.best_params_
best_rf = grid_search.best_estimator_

# Train the model
best_rf.fit(X_train, y_train)

# Predictions
train_predict= best_rf.predict(X_train)
test_predict = best_rf.predict(X_test)

# Calculate and print scores
training_scores(y_train, train_predict)
validation_scores(y_test, test_predict)
# Out:
#  ======= Training Classification Report ==========
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92     26047
#            1       0.83      0.58      0.68      8142
#
#     accuracy                           0.87     34189
#    macro avg       0.86      0.77      0.80     34189
# weighted avg       0.87      0.87      0.86     34189
#
# Training Accuracy:  0.872
#
#  ======= Testing Classification Report ==========
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91     11108
#            1       0.80      0.55      0.65      3545
#
#     accuracy                           0.86     14653
#    macro avg       0.84      0.75      0.78     14653
# weighted avg       0.85      0.86      0.85     14653
#
# Testing Accuracy:  0.858
